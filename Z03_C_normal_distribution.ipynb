# %% [markdown]
# # Wielowymiarowy rozkład normalny

# %%
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.mlab as mlab
from matplotlib import cm
from scipy.stats import multivariate_normal

# %% [markdown]
# # Zad.
# Narysujmy gęstość dwuwymiarowego rozkładu Normalnego o parametach
#
# * n=[0,0], cov = [[1,0],[0,1]]
# * n=[0,0], cov = [[2,0],[0,1]]
# * n=[0,0], cov = [[1,0],[0,2]]

# %%
n = [0,0]
cov1 = [[1,0],[0,1]]
cov2 = [[2,0],[0,1]]
cov3 = [[1,0],[0,2]]
rv = multivariate_normal(n, cov3)

# %%
x = np.linspace(-3,3,500)
y = np.linspace(-3,3,500)
X, Y = np.meshgrid(x,y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, rv.pdf(pos),cmap='viridis',linewidth=0)
plt.show()
# Out:
# C:\Users\krzys\AppData\Local\Temp\ipykernel_7116\2952081241.py:8: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# # Zad
# Narysujmy kontury gęstości dwuwymiarowego rozkładu Normalnego o parametach
#
# * n=[0,0], cov = [[1,0],[0,1]]
# * n=[0,0], cov = [[2,0],[0,1]]
# * n=[0,0], cov = [[1,0],[0,2]]

# %%
x = np.linspace(-3,3,500)
y = np.linspace(-3,3,500)
X, Y = np.meshgrid(x,y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y

plt.contourf(X, Y, pos)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 7>()
#       4 pos = np.empty(X.shape + (2,))
#       5 pos[:, :, 0] = X; pos[:, :, 1] = Y
# ----> 7 plt.contourf(X, Y, pos)
#       8 plt.show()
#
# File c:\python39\lib\site-packages\matplotlib\pyplot.py:2482, in contourf(data, *args, **kwargs)
#    2480 @_copy_docstring_and_deprecators(Axes.contourf)
#    2481 def contourf(*args, data=None, **kwargs):
# -> 2482     __ret = gca().contourf(
#    2483         *args, **({"data": data} if data is not None else {}),
#    2484         **kwargs)
#    2485     if __ret._A is not None: sci(__ret)  # noqa
#    2486     return __ret
#
# File c:\python39\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File c:\python39\lib\site-packages\matplotlib\axes\_axes.py:6317, in Axes.contourf(self, *args, **kwargs)
#    6308 """
#    6309 Plot filled contours.
#    6310
#    (...)
#    6314 %(contour_doc)s
#    6315 """
#    6316 kwargs['filled'] = True
# -> 6317 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6318 self._request_autoscale_view()
#    6319 return contours
#
# File c:\python39\lib\site-packages\matplotlib\contour.py:812, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, *args, **kwargs)
#     808     self.origin = mpl.rcParams['image.origin']
#     810 self._transform = transform
# --> 812 kwargs = self._process_args(*args, **kwargs)
#     813 self._process_levels()
#     815 self._extend_min = self.extend in ['min', 'both']
#
# File c:\python39\lib\site-packages\matplotlib\contour.py:1441, in QuadContourSet._process_args(self, corner_mask, *args, **kwargs)
#    1438     corner_mask = mpl.rcParams['contour.corner_mask']
#    1439 self._corner_mask = corner_mask
# -> 1441 x, y, z = self._contour_args(args, kwargs)
#    1443 _mask = ma.getmask(z)
#    1444 if _mask is ma.nomask or not _mask.any():
#
# File c:\python39\lib\site-packages\matplotlib\contour.py:1480, in QuadContourSet._contour_args(self, args, kwargs)
#    1478     args = args[1:]
#    1479 elif Nargs <= 4:
# -> 1480     x, y, z = self._check_xyz(args[:3], kwargs)
#    1481     args = args[3:]
#    1482 else:
#
# File c:\python39\lib\site-packages\matplotlib\contour.py:1508, in QuadContourSet._check_xyz(self, args, kwargs)
#    1505 z = ma.asarray(args[2], dtype=np.float64)
#    1507 if z.ndim != 2:
# -> 1508     raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1509 if z.shape[0] < 2 or z.shape[1] < 2:
#    1510     raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1511                     f"but has shape {z.shape}")
#
# TypeError: Input z must be 2D, not 3D

# %% [markdown]
# # Zad
# Wylosujmy próbkę z dwuwymiarowego rozkładu Normalnego o parametach
#
# * n=[0,0], cov = [[1,0],[0,1]]
# * n=[0,0], cov = [[2,0],[0,1]]
# * n=[0,0], cov = [[1,0],[0,2]]
#
# i narysuj odpowiedni wykres

# %%
x = rv.rvs(1000)

plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([-10,10])
axes.set_ylim([-10,10])
plt.plot(x[:, 0], x[:, 1], 'o')
plt.show()

# %%
# Out:
# [[ 0.62744416 -1.17738825]
#  [-0.19843004  0.46293456]
#  [ 0.73410687 -0.17302879]
#  [-0.67859714  0.123205  ]
#  [-1.17508555  0.33207958]
#  [ 0.80264166 -0.65766137]
#  [-0.1091463  -0.45194273]
#  [ 0.73143129  0.36718254]
#  [-0.48675575 -0.97227657]
#  [-0.24523008 -0.1189477 ]
#  [-0.08362987 -0.09775078]
#  [-0.82426774 -0.04991594]
#  [-0.85691168  0.75969305]
#  [-0.04225463 -0.12725555]
#  [ 1.04213989  0.6580119 ]
#  [ 0.20299129 -0.06181519]
#  [ 0.75770371 -1.5816685 ]
#  [-0.54427849 -0.68821693]
